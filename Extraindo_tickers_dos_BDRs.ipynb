# %% [markdown]
# # Extraindo dados de **TODOS os BDR's** negociados

# %% [markdown]
# Usaremos o portal **[InvestNews](https://investnews.com.br/)** para realizar a extração de dados.
# O caminho direto para os dados de nosso interesse, é [esse](https://investnews.com.br/financas/veja-a-lista-completa-dos-bdrs-disponiveis-para-pessoas-fisicas-na-b3/).

# %%
url = 'https://investnews.com.br/financas/veja-a-lista-completa-dos-bdrs-disponiveis-para-pessoas-fisicas-na-b3/'

# %% [markdown]
# Ao acessar o site, vemos que existem **duas tabelas** disponíveis, uma contendo as **BDR's das Ações** e outra com as **BDR's de ETF's**.

# %% [markdown]
# **Request com a Pandas**

# %% [markdown]
# Faremos uma tentativa inicial, da maneira mais básica possível, usando a função [read_html](https://pandas.pydata.org/docs/reference/api/pandas.read_html.html) da pandas para fazer a leitura do código fonte da página:

# %%
import pandas as pd

# %%
pd.read_html(url)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-3-5d8f83db45ac> in <cell line: 1>()
# ----> 1 pd.read_html(url)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend)
#    1210     io = stringify_path(io)
#    1211
# -> 1212     return _parse(
#    1213         flavor=flavor,
#    1214         io=io,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, **kwargs)
#     979
#     980         try:
# --> 981             tables = p.parse_tables()
#     982         except ValueError as caught:
#     983             # if `io` is an io-like object, check if it's seekable
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/html.py in parse_tables(self)
#     255         list of parsed (header, body, footer) tuples from tables.
#     256         """
# --> 257         tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     258         return (self._parse_thead_tbody_tfoot(table) for table in tables)
#     259
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/html.py in _build_doc(self)
#     814                     pass
#     815             else:
# --> 816                 raise e
#     817         else:
#     818             if not hasattr(r, "text_content"):
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/html.py in _build_doc(self)
#     795         try:
#     796             if is_url(self.io):
# --> 797                 with urlopen(self.io) as f:
#     798                     r = parse(f, parser=parser)
#     799             else:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in urlopen(*args, **kwargs)
#     268     import urllib.request
#     269
# --> 270     return urllib.request.urlopen(*args, **kwargs)
#     271
#     272
#
# /usr/lib/python3.10/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214     else:
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#     218 def install_opener(opener):
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     523         for processor in self.process_response.get(protocol, []):
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#     527         return response
#
# /usr/lib/python3.10/urllib/request.py in http_response(self, request, response)
#     632         # request was successfully received, understood, and accepted.
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#     636
#
# /usr/lib/python3.10/urllib/request.py in error(self, proto, *args)
#     561         if http_err:
#     562             args = (dict, 'default', 'http_error_default') + orig_args
# --> 563             return self._call_chain(*args)
#     564
#     565 # XXX probably also want an abstract factory that knows when it makes
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.10/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     641 class HTTPDefaultErrorHandler(BaseHandler):
#     642     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     644
#     645 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 403: Forbidden

# %% [markdown]
# Vemos que houve um ["erro"](https://www.pythonpool.com/urllib-error-httperror-http-error-403-forbidden/) de acesso, que na realidade é uma proibição de acesso, uma espécie de segurança impedindo o acesso de maneira artificial para evitar ataques virtuais.
# Precisamos melhorar nossa apresentação ao site, ou seja, acessá-lo de maneira mais amigável, deixando claro que mesmo estando fazendo uma extração via python, eu tenho uma identidade.

# %% [markdown]
# **Request com a urllib**

# %% [markdown]
# Nesta tentativa, usaremos a biblioteca [urllib](https://docs.python.org/3/library/urllib.html), que permite adicionar parâmetros no request, tornando nosso acesso mais orgânico:

# %%
from urllib import request
from urllib.request import Request, urlopen

# %%
pedido_site = Request(url)

# %% [markdown]
# Fizemos o pedido de acesso, e por hora não tivemos intercorrências.

# %% [markdown]
# Agora, vamos informar o que desejamos fazer com esse pedido:

# %%
urlopen(pedido_site).read()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-6-61fd5342acca> in <cell line: 1>()
# ----> 1 urlopen(pedido_site).read()
#
# /usr/lib/python3.10/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214     else:
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#     218 def install_opener(opener):
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     523         for processor in self.process_response.get(protocol, []):
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#     527         return response
#
# /usr/lib/python3.10/urllib/request.py in http_response(self, request, response)
#     632         # request was successfully received, understood, and accepted.
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#     636
#
# /usr/lib/python3.10/urllib/request.py in error(self, proto, *args)
#     561         if http_err:
#     562             args = (dict, 'default', 'http_error_default') + orig_args
# --> 563             return self._call_chain(*args)
#     564
#     565 # XXX probably also want an abstract factory that knows when it makes
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.10/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     641 class HTTPDefaultErrorHandler(BaseHandler):
#     642     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     644
#     645 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 403: Forbidden

# %% [markdown]
# Ao informar nosso desejo de ler a informação do site, tivemos a mesma negativa por bloqueio, sinal de que as catacterísticas padrão da urllib não foram suficientes.

# %% [markdown]
# **Novo Request com a urllib, agora com mais parâmetros de identificação**

# %% [markdown]
# Melhorando argumentos para acesso:

# %%
pedido_site = Request(url, headers = {"User-Agent":"Mozilla/5.0"})
urlopen(pedido_site).read()

# %% [markdown]
# Conseguimos obter o código fonte do site, mas ainda de maneira desordenada.

# %% [markdown]
# Precisamos ordenar essas informações para que possamos coletar somente o que seja de nosso interesse.
# Para isso faremos uma breve análise usando novamente a função read_html.

# %%
codigo_html = urlopen(pedido_site).read()

# %%
pd.read_html(codigo_html)
# Out:
# [                 0       1                                       2  \
#  0          EMPRESA  CÓDIGO                                   SETOR
#  1               3M  MMMC34                 Indústria diversificada
#  2         AB INBEV  ABUD34                                 Bebidas
#  3          ABB LTD  A1BB34                              Industrial
#  4           ABBOTT  ABTT34                           Farmacêuticos
#  ..             ...     ...                                     ...
#  704  RAYTHEON TECH  RYTT34                              Industrial
#  705   SCHLUMBERGER  SLBG34  Equipamentos e Serviços de Combustível
#  706        TIFFANY  TIFF34                               Joalheria
#  707     US BANCORP  USBC34                  Instituição Financeira
#  708         XP INC  XPBR31                              Financeiro
#
#                    3
#  0    PAÍS DE ORIGEM
#  1               EUA
#  2           Bélgica
#  3       Switzerland
#  4               EUA
#  ..              ...
#  704             EUA
#  705             EUA
#  706             EUA
#  707             EUA
#  708          Brasil
#
#  [709 rows x 4 columns],
#                     0                     1                     2
#  0     Nome de pregão  Código de negociação  Paridade (Cota: BDR)
#  1       MSCI Asia JP                BAAX39                  1:10
#  2          MSCI ACWI                BACW39                  1:10
#  3    Trust MSCI EAFE                BEGD39                  1:08
#  4      Trust MSCI US                BEGD39                  1:10
#  5         MSCI China                BCHI39                  1:08
#  6         Gold Trust                BIAU39                  1:02
#  7          MSCI EAFE                BIAU39                  1:08
#  8         MSCI Japan                BEWJ39                  1:08
#  9      CORE MSCI EMK                BIEM39                  1:06
#  10  Core MSCI Europe                BIEU39                  1:06
#  11       Core SP 500                BIVB39                  1:40
#  12      FT NSQ GREEN                BQCL39                   1:8
#  13      MSCI EMGMARK                BEEM39                   1:6
#  14           MSCI UK                BEWU39                   1:3
#  15      MSCI GERMANY                BEWG39                   1:3
#  16      SILVER TRUST                BSLV39                   1:3
#  17      SELECT DIVID                BDVY39                  1:10
#  18      CORE SP TOTA                BITO39                  1:10
#  19      US FINANCIAL                BIYF39                  1:15
#  20      GLOBAL INFRA                BIGF39                   1:4
#  21     GLOBAL HEALTH                BIXJ39                   1:8
#  22       GLOBAL TECH                BIXN39                  1:30
#  23      INC ESG AWAR                BEGE39                   1:4
#  24      NASDAQ BIOTC                BIBB39                  1:15]

# %%
type(pd.read_html(codigo_html))
# Out:
# list

# %% [markdown]
# Vemos que existe uma ordenação dentro do site, aparentemente dividido por tabelas.
# Ao pedir o tipo do elemento, nos retorna "lista".
# Possivelmente seja uma lista de dataframes, onde cada elemento seja um dataframe.

# %%
pd.read_html(codigo_html)[0]
# Out:
#                  0       1                                       2  \
# 0          EMPRESA  CÓDIGO                                   SETOR
# 1               3M  MMMC34                 Indústria diversificada
# 2         AB INBEV  ABUD34                                 Bebidas
# 3          ABB LTD  A1BB34                              Industrial
# 4           ABBOTT  ABTT34                           Farmacêuticos
# ..             ...     ...                                     ...
# 704  RAYTHEON TECH  RYTT34                              Industrial
# 705   SCHLUMBERGER  SLBG34  Equipamentos e Serviços de Combustível
# 706        TIFFANY  TIFF34                               Joalheria
# 707     US BANCORP  USBC34                  Instituição Financeira
# 708         XP INC  XPBR31                              Financeiro
#
#                   3
# 0    PAÍS DE ORIGEM
# 1               EUA
# 2           Bélgica
# 3       Switzerland
# 4               EUA
# ..              ...
# 704             EUA
# 705             EUA
# 706             EUA
# 707             EUA
# 708          Brasil
#
# [709 rows x 4 columns]

# %% [markdown]
# No elemento 0 temos as informações dos **BDR's das Ações**;
#
# No elemento 1 temos as informações dos **BDR's de ETF's**.

# %% [markdown]
# Agora vamos:
# *   1- **Criar um dataframe** com a elemento [0] da lista;
# *   2- **Renomear índice das colunas**, usando as informações da linha 0.
# *   3- **Eliminar** informações da **linha 0**.

# %%
df_bdr = pd.read_html(codigo_html)[0]

# %%
df_bdr.columns = df_bdr.iloc[0]

# %%
df_bdr.drop(0, axis = 0, inplace = True)

# %%
df_bdr.head()
# Out:
# 0   EMPRESA  CÓDIGO                           SETOR PAÍS DE ORIGEM
# 1        3M  MMMC34         Indústria diversificada            EUA
# 2  AB INBEV  ABUD34                         Bebidas        Bélgica
# 3   ABB LTD  A1BB34                      Industrial    Switzerland
# 4    ABBOTT  ABTT34                   Farmacêuticos            EUA
# 5    ABBVIE  ABBV34  Medicamentos e Outros Produtos            EUA

# %%
df_bdr.shape
# Out:
# (708, 4)

# %% [markdown]
# Temos **708 BDR's** para trabalhar.

# %% [markdown]
# Uma das possibilidades seria extrair os tickers em lista, para uso posterior:

# %%
bdr_ticker = list(df_bdr['CÓDIGO'])
bdr_ticker
# Out:
# ['MMMC34',
#  'ABUD34',
#  'A1BB34',
#  'ABTT34',
#  'ABBV34',
#  'A1BM34',
#  'ATVI34',
#  'ADBE34',
#  'A1AP34',
#  'A1MD34',
#  'A1EG34',
#  'A1ES34',
#  'A1FL34',
#  'AIRB34',
#  'A1GI34',
#  'A1PD34',
#  'A1KA34',
#  'A1LK34',
#  'A1LB34',
#  'A1RE34',
#  'A1LX34',
#  'BABA34',
#  'A1LG34',
#  'A1GN34',
#  'A1LL34',
#  'A1EN34',
#  'A1TT34',
#  'A1LN34',
#  'GOGL34',
#  'GOGL35',
#  'A1YX34',
#  'MOOO34',
#  'A2MC34',
#  'A1CR34',
#  'A1EE34',
#  'A1MX34',
#  'AALL34',
#  'A1EP34',
#  'T1OW34',
#  'A1WK34',
#  'A1MP34',
#  'A1MB34',
#  'A1ME34',
#  'AMGN34',
#  'A1PH34',
#  'A1DI34',
#  'A1UA34',
#  'A1NS34',
#  'A1NT34',
#  'A1OS34',
#  'A1ON34',
#  'A1PA34',
#  'A1IV34',
#  'AAPL34',
#  'A1MT34',
#  'APTV34',
#  'ARMT34',
#  'A1DM34',
#  'A1RG34',
#  'A1NE34',
#  'AWII34',
#  'A1JG34',
#  'A1SN34',
#  'ASML34',
#  'A1SU34',
#  'A1ZN34',
#  'T1AM34',
#  'A1TM34',
#  'A1UT34',
#  'A1TH34',
#  'ADPR34',
#  'AZOI34',
#  'A2VL34',
#  'A1VB34',
#  'A1VY34',
#  'BIDU34',
#  'B1KR34',
#  'B1LL34',
#  'B1SA34',
#  'BOAC34',
#  'B1CS34',
#  'B1AX34',
#  'B1BT34',
#  'B1DX34',
#  'B1GN34',
#  'BBYY34',
#  'BHPG34',
#  'B1BL34',
#  'BILB34',
#  'B1IL34',
#  'B2HI34',
#  'BIIB34',
#  'B1MR34',
#  'B1NT34',
#  'T1CH34',
#  'BLAK34',
#  'BKNG34',
#  'B1WA34',
#  'BOXP34',
#  'B1SX34',
#  'B1PP34',
#  'B1TI34',
#  'AVGO34',
#  'B1RF34',
#  'B1AM34',
#  'B1FC34',
#  'B2MB34',
#  'C1AB34',
#  'C1OG34',
#  'C1DN34',
#  'C1PB34',
#  'C2PT34',
#  'CNIC34',
#  'CPRL34',
#  'CAJI34',
#  'CAON34',
#  'CAPH34',
#  'C1AH34',
#  'K1MX34',
#  'C1CL34',
#  'C1RR34',
#  'CRIN34',
#  'C1BO34',
#  'C1BR34',
#  'C1BS34',
#  'C1DW34',
#  'C1NS34',
#  'C1NC34',
#  'C1NP34',
#  'C1ER34',
#  'C1FI34',
#  'C1HR34',
#  'CHCM34',
#  'C1HK34',
#  'L1FC34',
#  'C1HL34',
#  'C1HI34',
#  'C1MG34',
#  'C1BL34',
#  'C1HT34',
#  'CHDC34',
#  'C1IC34',
#  'CINF34',
#  'C1TA34',
#  'CSCO34',
#  'CTGP34',
#  'C1FG34',
#  'C1TX34',
#  'CLXC34',
#  'CHME34',
#  'C1MS34',
#  'C1EO34',
#  'CTSH34',
#  'CMCS34',
#  'C1MA34',
#  'C1AG34',
#  'C1XO34',
#  'E1DI34',
#  'STZB34',
#  'C1OO34',
#  'C1PR34',
#  'COPH34',
#  'G1LW34',
#  'C1TV34',
#  'C1GP34',
#  'COWC34',
#  'COTY34',
#  'C1OU34',
#  'CRDA34',
#  'C1SU34',
#  'CRHP34',
#  'C1CI34',
#  'CSXC34',
#  'CRIP34',
#  'C1MI34',
#  'CVSH34',
#  'DHER34',
#  'D1RI34',
#  'D1DG34',
#  'DVAI34',
#  'DEEC34',
#  'D1EL34',
#  'DEAI34',
#  'XRAY34',
#  'DBAG34',
#  'D1VN34',
#  'D1EX34',
#  'DEOP34',
#  'F1AN34',
#  'D1LR34',
#  'D1FS34',
#  'DCVY34',
#  'DCVY35',
#  'D1IS34',
#  'D1OC34',
#  'DGCO34',
#  'DLTR34',
#  'D1OM34',
#  'D2PZ34',
#  'D2AS34',
#  'D1OV34',
#  'D1OW34',
#  'D1HI34',
#  'R1DY34',
#  'D1TE34',
#  'D1RE34',
#  'D1XC34',
#  'E1MN34',
#  'E1TN34',
#  'EBAY34',
#  'E1CL34',
#  'E1CO34',
#  'E1IX34',
#  'E1WL34',
#  'E2ST34',
#  'EAIN34',
#  'E1MR34',
#  'E1NI34',
#  'E1TR34',
#  'E2PD34',
#  'E1OG34',
#  'E1FX34',
#  'EQIX34',
#  'E1QN34',
#  'E1QR34',
#  'E1RI34',
#  'E1SS34',
#  'ELCI34',
#  'E2TS34',
#  'E2EF34',
#  'E1VE34',
#  'E1VR34',
#  'E1SE34',
#  'E1XC34monde',
#  'EXGR34',
#  'E1XP34',
#  'E1XR34',
#  'EXXO34',
#  'F1FI34',
#  'FBOK34',
#  'FASL34',
#  'F1SL34',
#  'F1RI34',
#  'F1NI34',
#  'FFTD34',
#  'F1RC34',
#  'FSLR34',
#  'F1EC34',
#  'F1IS34',
#  'F2VR34',
#  'FLTC34',
#  'F1LI34',
#  'F1LS34',
#  'F1MC34',
#  'FDMO34',
#  'F1TN34',
#  'F1TV34',
#  'F1BH34',
#  'FOXC34',
#  'F2NV34',
#  'F1RA34',
#  'FCXO34',
#  'FMSC34',
#  'G1LP34',
#  'GPSI34',
#  'G1RM34',
#  'G1AR34',
#  'G1DS34',
#  'GEOO34',
#  'G1MI34',
#  'GMCO34',
#  'G1PC34',
#  'GPRK34',
#  'GILD34',
#  'G1SK34',
#  'G1PI34',
#  'G1LL34',
#  'G2DD34',
#  'G1FI34',
#  'GSGI34',
#  'GPRO34',
#  'H1RB34',
#  'HALI34',
#  'H1BI34',
#  'THGI34',
#  'H1OG34',
#  'H1IG34',
#  'H1AS34',
#  'H1CA34',
#  'H1DB34',
#  'P1EA34',
#  'H1EI34',
#  'H1SI34',
#  'HSHY34',
#  'H1ES34',
#  'H1PE34',
#  'H1LT34',
#  'H1FC34',
#  'H1OL34',
#  'HOME34',
#  'HOND34',
#  'H1ZN34',
#  'H1RL34',
#  'H1ST34',
#  'ARNC34',
#  'H1SB34',
#  'H1TH34',
#  'H2UB34',
#  'H1UM34',
#  'H1BA34',
#  'H1II34',
#  'I1AC34',
#  'I1BN34',
#  'I1EX34',
#  'I1DX34',
#  'I1NF34',
#  'I1TW34',
#  'I1LM34',
#  'I1NC34',
#  'I1FO34',
#  'INGG3',
#  'I1RP34',
#  'ITLC34',
#  'I1CE34',
#  'I1HG34',
#  'I1PC34',
#  'I1FF34',
#  'I1PH34',
#  'INTU34',
#  'I1SR34',
#  'I1VZ34',
#  'ISBC34',
#  'I1PG34',
#  'I1QY34',
#  'I1QV34',
#  'I1RM34',
#  'J1KH34',
#  'J1EG34',
#  'J1BH34',
#  'JDCO34',
#  'J1EF34',
#  'J1CI34',
#  'JPMC34',
#  'J1NP34',
#  'K1CS34',
#  'K1BF34',
#  'K1EL34',
#  'KMPR34',
#  'K1EY34',
#  'K1SG34',
#  'K1IM34',
#  'KMIC34',
#  'K1LA34',
#  'K1SS34',
#  'PHGN34',
#  'K1RC34',
#  'K1TC34',
#  'LBRN34',
#  'L1HX34',
#  'L1CA34',
#  'L1RC34',
#  'L1WH34',
#  'L1VS34',
#  'L1EG34',
#  'L1DO34',
#  'L1EN34',
#  'LBRD34',
#  'L1BT34',
#  'L1BT35',
#  'LSXM34',
#  'LSXM35',
#  'LILY34',
#  'L1NC34',
#  'L1IN34',
#  'L1YV34',
#  'L1KQ34',
#  'L1YG34',
#  'L1OE34',
#  'LOWC34',
#  'L1UL34',
#  'L1MN34',
#  'L1YB34',
#  'M1TB34',
#  'MACY34',
#  'M1RO34',
#  'M1PC34',
#  'MKLC34',
#  'M1KT34',
#  'M1TT34',
#  'M1MC34',
#  'M1LM34',
#  'M1AS34',
#  'M1TC34',
#  'M1XI34',
#  'M1KC34',
#  'MCDC34',
#  'M1CK34',
#  'MDTC34',
#  'M1LC34',
#  'MELI34',
#  'MRCK34',
#  'M1TD34',
#  'M1GM34',
#  'M1CH34',
#  'MUTC34',
#  'MSFT34',
#  'M1AA34',
#  'M1UF34',
#  'M1BT34',
#  'M1RN34',
#  'M1HK34',
#  'M1CB34',
#  'MDLZ34',
#  'M1DB34',
#  'M1NS34',
#  'MCOR34',
#  'MOSC34',
#  'M1SI34',
#  'M1SC34',
#  'N1DA34',
#  'N1GG34',
#  'N1OV34',
#  'N1WG34',
#  'N1TA34',
#  'NETE34',
#  'NFLX34',
#  'N1BI34',
#  'E1DU34',
#  'N1WL34',
#  'N1EM34',
#  'N1WS34',
#  'N1WS35',
#  'NEXT34',
#  'N1IC34',
#  'N1LS34',
#  'N1IS34',
#  'NOKI34',
#  'NMRH34',
#  'J1WN34',
#  'N1SC34',
#  'N1TR34',
#  'NOCG34',
#  'N1CL34',
#  'N1VS34',
#  'N1VO34',
#  'N1RG34',
#  'NUBR33',
#  'N1UE34',
#  'NVDC34',
#  'N1VR34',
#  'N1XP34',
#  'OXYP34',
#  'O1KT34',
#  'O1DF34',
#  'O1MC34',
#  'O1KE34',
#  'ORLY34',
#  'I1XC34',
#  'O1TI34',
#  'P1AC34',
#  'P1KG34',
#  'PAGS34',
#  'P2LT34',
#  'P1HC34',
#  'P1AY34',
#  'P1YC34',
#  'PYPL34',
#  'P1NR34',
#  'P1BC34',
#  'P1KI34',
#  'P1RG34',
#  'PTCH34',
#  'P2IN34',
#  'PFIZ34',
#  'PGCO34',
#  'PHMO34',
#  'P1SX34',
#  'P1DD34',
#  'P1NW34',
#  'P1IO34',
#  'P2LN34',
#  'PNCS34',
#  'P1KX34',
#  'P1PG34',
#  'P1PL34',
#  'P1FG34',
#  'P2CO34',
#  'P1LD34',
#  'P1DT34',
#  'P1UK34',
#  'T1LK34',
#  'P1EG34',
#  'P1SA34',
#  'P1HM34',
#  'P1VH34',
#  'Q1RV34',
#  'QCOM34',
#  'Q1UA34',
#  'Q1UE34',
#  'R1LC34',
#  'R1JF34',
#  'RDSA34',
#  'R1IN34',
#  'R1EG34',
#  'R2DF34',
#  'REGN34',
#  'R1FC34',
#  'R1EL34',
#  'R1SG34',
#  'R1MD34',
#  'RIOT34',
#  'R2HH34',
#  'R1HI34',
#  'R2BL34',
#  'R1OK34',
#  'R1KU34',
#  'R1OL34',
#  'R1OP34',
#  'ROST34',
#  'R1CL34',
#  'RDSA35',
#  'R1YA34',
#  'SPGI34',
#  'SSFO34',
#  'BCSA34',
#  'SAPP34',
#  'S1RP34',
#  'S1BA34',
#  'SCHW34',
#  'S1TX34',
#  'S1EA34',
#  'S1GE34',
#  'S1RE34',
#  'N1OW34',
#  'S1BS34',
#  'SBNY34',
#  'SIMN34',
#  'SRXM34',
#  'S1KM34',
#  'S1SL34',
#  'S1LG34',
#  'S1NN34',
#  'S1NA34',
#  'S2QS34',
#  'SNEC34',
#  'S1OU34',
#  'S1PL34',
#  'S1PO34',
#  'S1SN34',
#  'S1WK34',
#  'S1TT34',
#  'S1TE34',
#  'SLBC34',
#  'STMN34',
#  'S2TO34',
#  'S1YK34',
#  'S1MF34',
#  'S1IV34',
#  'S1YM34',
#  'S1YF34',
#  'S1NP34',
#  'S1YY34',
#  'T1RO34',
#  'TSMC34',
#  'TAKP34',
#  'T1TW34',
#  'T1AL34',
#  'TPRY34',
#  'T1EL34',
#  'T1EC34',
#  'T1FX34',
#  'TLNC34',
#  'T2PX34',
#  'T1SS34',
#  'TXSA34',
#  'TSLA34',
#  'T1EV34',
#  'T1XT34',
#  'S1JM34',
#  'P1GR34',
#  'S1HW34',
#  'T1SO34',
#  'TMOS34',
#  'TJXC34',
#  'T1MU34',
#  'TMCO34',
#  'T1SC34',
#  'T1DG34',
#  'RIGG34',
#  'TRVC34',
#  'T1RI34',
#  'T1WL34',
#  'TWTR34',
#  'TSNF34',
#  'U1BE34',
#  'UBSG34',
#  'U1DR34',
#  'P2AT34',
#  'U1LT34',
#  'U1AI34',
#  'ULEV34',
#  'U1NL34',
#  'UPAC34',
#  'U1AL34',
#  'U1RI34',
#  'UNHH34',
#  'U1HS34',
#  'U1NM34',
#  'UPSS34',
#  'U2PW34',
#  'USSX34',
#  'VLOE34',
#  'VLYB34',
#  'V1AR34',
#  'V2EE34',
#  'V1TA34',
#  'VRSN34',
#  'V1RS34',
#  'VERZ34',
#  'VRTX34',
#  'VFCO34',
#  'V2ME34',
#  'V1IP34',
#  'V1OD34',
#  'V1NO34',
#  'V1MC34',
#  'W1AB34',
#  'WALM34',
#  'WGBA34',
#  'W1MG34',
#  'W1MC34',
#  'WATC34',
#  'W1SO34',
#  'W2YF34',
#  'W1EC34',
#  'W1BO34',
#  'WFCO34',
#  'W1EL34',
#  'W2ST34',
#  'WABC34',
#  'W1DC34',
#  'WUNI34',
#  'W1BK34',
#  'W1RK34',
#  'W1YC34',
#  'W1HR34',
#  'W1MB34',
#  'W1LT34',
#  'W1IX34',
#  'W1DA34',
#  'W1PP34',
#  'W1RB34',
#  'G1WW34',
#  'W1YN34',
#  'X1EL34',
#  'X1LN34',
#  'X1YL34',
#  'YUMR34',
#  'Z1BR34',
#  'Z2EN34',
#  'Z2LL34',
#  'Z1BH34',
#  'Z1IO34',
#  'Z1TS34',
#  'Z1OM34',
#  'Z1TO34',
#  'ACNB34',
#  'AIGB34',
#  'AXPB34',
#  'ATTB34',
#  'BERK34',
#  'BONY34',
#  'BOEI34',
#  'BMYB34',
#  'DUKB34',
#  'DDNB34',
#  'FDXB34',
#  'FMXB34',
#  'GDBR34',
#  'HONB34',
#  'HPQB34',
#  'IBMB34',
#  'JNJB34',
#  'KMBB34',
#  'KHCB34',
#  'LMTB34',
#  'METB34',
#  'MSBR34',
#  'PEPB34',
#  'SBUB34',
#  'TGTB34',
#  'TEXA34',
#  'VISA34',
#  'DISB34',
#  'XRXB34',
#  'AMZO34',
#  'CATP34',
#  'CHVX34',
#  'COCA34',
#  'COLG34',
#  'MSCD34',
#  'NIKE34',
#  'ORCL34',
#  'RYTT34',
#  'SLBG34',
#  'TIFF34',
#  'USBC34',
#  'XPBR31']

# %% [markdown]
# Assim, por exemplo, conseguimos extrair dados de cotação com a [yfinance](https://pypi.org/project/yfinance/).
#
# Por padrão, a yfinance usa ".SA" ao final de cada ticker, precisamos fazer esse incremento.

# %%
bdr_sa = [bdr + '.SA' for bdr in bdr_ticker]
bdr_sa
# Out:
# ['MMMC34.SA',
#  'ABUD34.SA',
#  'A1BB34.SA',
#  'ABTT34.SA',
#  'ABBV34.SA',
#  'A1BM34.SA',
#  'ATVI34.SA',
#  'ADBE34.SA',
#  'A1AP34.SA',
#  'A1MD34.SA',
#  'A1EG34.SA',
#  'A1ES34.SA',
#  'A1FL34.SA',
#  'AIRB34.SA',
#  'A1GI34.SA',
#  'A1PD34.SA',
#  'A1KA34.SA',
#  'A1LK34.SA',
#  'A1LB34.SA',
#  'A1RE34.SA',
#  'A1LX34.SA',
#  'BABA34.SA',
#  'A1LG34.SA',
#  'A1GN34.SA',
#  'A1LL34.SA',
#  'A1EN34.SA',
#  'A1TT34.SA',
#  'A1LN34.SA',
#  'GOGL34.SA',
#  'GOGL35.SA',
#  'A1YX34.SA',
#  'MOOO34.SA',
#  'A2MC34.SA',
#  'A1CR34.SA',
#  'A1EE34.SA',
#  'A1MX34.SA',
#  'AALL34.SA',
#  'A1EP34.SA',
#  'T1OW34.SA',
#  'A1WK34.SA',
#  'A1MP34.SA',
#  'A1MB34.SA',
#  'A1ME34.SA',
#  'AMGN34.SA',
#  'A1PH34.SA',
#  'A1DI34.SA',
#  'A1UA34.SA',
#  'A1NS34.SA',
#  'A1NT34.SA',
#  'A1OS34.SA',
#  'A1ON34.SA',
#  'A1PA34.SA',
#  'A1IV34.SA',
#  'AAPL34.SA',
#  'A1MT34.SA',
#  'APTV34.SA',
#  'ARMT34.SA',
#  'A1DM34.SA',
#  'A1RG34.SA',
#  'A1NE34.SA',
#  'AWII34.SA',
#  'A1JG34.SA',
#  'A1SN34.SA',
#  'ASML34.SA',
#  'A1SU34.SA',
#  'A1ZN34.SA',
#  'T1AM34.SA',
#  'A1TM34.SA',
#  'A1UT34.SA',
#  'A1TH34.SA',
#  'ADPR34.SA',
#  'AZOI34.SA',
#  'A2VL34.SA',
#  'A1VB34.SA',
#  'A1VY34.SA',
#  'BIDU34.SA',
#  'B1KR34.SA',
#  'B1LL34.SA',
#  'B1SA34.SA',
#  'BOAC34.SA',
#  'B1CS34.SA',
#  'B1AX34.SA',
#  'B1BT34.SA',
#  'B1DX34.SA',
#  'B1GN34.SA',
#  'BBYY34.SA',
#  'BHPG34.SA',
#  'B1BL34.SA',
#  'BILB34.SA',
#  'B1IL34.SA',
#  'B2HI34.SA',
#  'BIIB34.SA',
#  'B1MR34.SA',
#  'B1NT34.SA',
#  'T1CH34.SA',
#  'BLAK34.SA',
#  'BKNG34.SA',
#  'B1WA34.SA',
#  'BOXP34.SA',
#  'B1SX34.SA',
#  'B1PP34.SA',
#  'B1TI34.SA',
#  'AVGO34.SA',
#  'B1RF34.SA',
#  'B1AM34.SA',
#  'B1FC34.SA',
#  'B2MB34.SA',
#  'C1AB34.SA',
#  'C1OG34.SA',
#  'C1DN34.SA',
#  'C1PB34.SA',
#  'C2PT34.SA',
#  'CNIC34.SA',
#  'CPRL34.SA',
#  'CAJI34.SA',
#  'CAON34.SA',
#  'CAPH34.SA',
#  'C1AH34.SA',
#  'K1MX34.SA',
#  'C1CL34.SA',
#  'C1RR34.SA',
#  'CRIN34.SA',
#  'C1BO34.SA',
#  'C1BR34.SA',
#  'C1BS34.SA',
#  'C1DW34.SA',
#  'C1NS34.SA',
#  'C1NC34.SA',
#  'C1NP34.SA',
#  'C1ER34.SA',
#  'C1FI34.SA',
#  'C1HR34.SA',
#  'CHCM34.SA',
#  'C1HK34.SA',
#  'L1FC34.SA',
#  'C1HL34.SA',
#  'C1HI34.SA',
#  'C1MG34.SA',
#  'C1BL34.SA',
#  'C1HT34.SA',
#  'CHDC34.SA',
#  'C1IC34.SA',
#  'CINF34.SA',
#  'C1TA34.SA',
#  'CSCO34.SA',
#  'CTGP34.SA',
#  'C1FG34.SA',
#  'C1TX34.SA',
#  'CLXC34.SA',
#  'CHME34.SA',
#  'C1MS34.SA',
#  'C1EO34.SA',
#  'CTSH34.SA',
#  'CMCS34.SA',
#  'C1MA34.SA',
#  'C1AG34.SA',
#  'C1XO34.SA',
#  'E1DI34.SA',
#  'STZB34.SA',
#  'C1OO34.SA',
#  'C1PR34.SA',
#  'COPH34.SA',
#  'G1LW34.SA',
#  'C1TV34.SA',
#  'C1GP34.SA',
#  'COWC34.SA',
#  'COTY34.SA',
#  'C1OU34.SA',
#  'CRDA34.SA',
#  'C1SU34.SA',
#  'CRHP34.SA',
#  'C1CI34.SA',
#  'CSXC34.SA',
#  'CRIP34.SA',
#  'C1MI34.SA',
#  'CVSH34.SA',
#  'DHER34.SA',
#  'D1RI34.SA',
#  'D1DG34.SA',
#  'DVAI34.SA',
#  'DEEC34.SA',
#  'D1EL34.SA',
#  'DEAI34.SA',
#  'XRAY34.SA',
#  'DBAG34.SA',
#  'D1VN34.SA',
#  'D1EX34.SA',
#  'DEOP34.SA',
#  'F1AN34.SA',
#  'D1LR34.SA',
#  'D1FS34.SA',
#  'DCVY34.SA',
#  'DCVY35.SA',
#  'D1IS34.SA',
#  'D1OC34.SA',
#  'DGCO34.SA',
#  'DLTR34.SA',
#  'D1OM34.SA',
#  'D2PZ34.SA',
#  'D2AS34.SA',
#  'D1OV34.SA',
#  'D1OW34.SA',
#  'D1HI34.SA',
#  'R1DY34.SA',
#  'D1TE34.SA',
#  'D1RE34.SA',
#  'D1XC34.SA',
#  'E1MN34.SA',
#  'E1TN34.SA',
#  'EBAY34.SA',
#  'E1CL34.SA',
#  'E1CO34.SA',
#  'E1IX34.SA',
#  'E1WL34.SA',
#  'E2ST34.SA',
#  'EAIN34.SA',
#  'E1MR34.SA',
#  'E1NI34.SA',
#  'E1TR34.SA',
#  'E2PD34.SA',
#  'E1OG34.SA',
#  'E1FX34.SA',
#  'EQIX34.SA',
#  'E1QN34.SA',
#  'E1QR34.SA',
#  'E1RI34.SA',
#  'E1SS34.SA',
#  'ELCI34.SA',
#  'E2TS34.SA',
#  'E2EF34.SA',
#  'E1VE34.SA',
#  'E1VR34.SA',
#  'E1SE34.SA',
#  'E1XC34monde.SA',
#  'EXGR34.SA',
#  'E1XP34.SA',
#  'E1XR34.SA',
#  'EXXO34.SA',
#  'F1FI34.SA',
#  'FBOK34.SA',
#  'FASL34.SA',
#  'F1SL34.SA',
#  'F1RI34.SA',
#  'F1NI34.SA',
#  'FFTD34.SA',
#  'F1RC34.SA',
#  'FSLR34.SA',
#  'F1EC34.SA',
#  'F1IS34.SA',
#  'F2VR34.SA',
#  'FLTC34.SA',
#  'F1LI34.SA',
#  'F1LS34.SA',
#  'F1MC34.SA',
#  'FDMO34.SA',
#  'F1TN34.SA',
#  'F1TV34.SA',
#  'F1BH34.SA',
#  'FOXC34.SA',
#  'F2NV34.SA',
#  'F1RA34.SA',
#  'FCXO34.SA',
#  'FMSC34.SA',
#  'G1LP34.SA',
#  'GPSI34.SA',
#  'G1RM34.SA',
#  'G1AR34.SA',
#  'G1DS34.SA',
#  'GEOO34.SA',
#  'G1MI34.SA',
#  'GMCO34.SA',
#  'G1PC34.SA',
#  'GPRK34.SA',
#  'GILD34.SA',
#  'G1SK34.SA',
#  'G1PI34.SA',
#  'G1LL34.SA',
#  'G2DD34.SA',
#  'G1FI34.SA',
#  'GSGI34.SA',
#  'GPRO34.SA',
#  'H1RB34.SA',
#  'HALI34.SA',
#  'H1BI34.SA',
#  'THGI34.SA',
#  'H1OG34.SA',
#  'H1IG34.SA',
#  'H1AS34.SA',
#  'H1CA34.SA',
#  'H1DB34.SA',
#  'P1EA34.SA',
#  'H1EI34.SA',
#  'H1SI34.SA',
#  'HSHY34.SA',
#  'H1ES34.SA',
#  'H1PE34.SA',
#  'H1LT34.SA',
#  'H1FC34.SA',
#  'H1OL34.SA',
#  'HOME34.SA',
#  'HOND34.SA',
#  'H1ZN34.SA',
#  'H1RL34.SA',
#  'H1ST34.SA',
#  'ARNC34.SA',
#  'H1SB34.SA',
#  'H1TH34.SA',
#  'H2UB34.SA',
#  'H1UM34.SA',
#  'H1BA34.SA',
#  'H1II34.SA',
#  'I1AC34.SA',
#  'I1BN34.SA',
#  'I1EX34.SA',
#  'I1DX34.SA',
#  'I1NF34.SA',
#  'I1TW34.SA',
#  'I1LM34.SA',
#  'I1NC34.SA',
#  'I1FO34.SA',
#  'INGG3.SA',
#  'I1RP34.SA',
#  'ITLC34.SA',
#  'I1CE34.SA',
#  'I1HG34.SA',
#  'I1PC34.SA',
#  'I1FF34.SA',
#  'I1PH34.SA',
#  'INTU34.SA',
#  'I1SR34.SA',
#  'I1VZ34.SA',
#  'ISBC34.SA',
#  'I1PG34.SA',
#  'I1QY34.SA',
#  'I1QV34.SA',
#  'I1RM34.SA',
#  'J1KH34.SA',
#  'J1EG34.SA',
#  'J1BH34.SA',
#  'JDCO34.SA',
#  'J1EF34.SA',
#  'J1CI34.SA',
#  'JPMC34.SA',
#  'J1NP34.SA',
#  'K1CS34.SA',
#  'K1BF34.SA',
#  'K1EL34.SA',
#  'KMPR34.SA',
#  'K1EY34.SA',
#  'K1SG34.SA',
#  'K1IM34.SA',
#  'KMIC34.SA',
#  'K1LA34.SA',
#  'K1SS34.SA',
#  'PHGN34.SA',
#  'K1RC34.SA',
#  'K1TC34.SA',
#  'LBRN34.SA',
#  'L1HX34.SA',
#  'L1CA34.SA',
#  'L1RC34.SA',
#  'L1WH34.SA',
#  'L1VS34.SA',
#  'L1EG34.SA',
#  'L1DO34.SA',
#  'L1EN34.SA',
#  'LBRD34.SA',
#  'L1BT34.SA',
#  'L1BT35.SA',
#  'LSXM34.SA',
#  'LSXM35.SA',
#  'LILY34.SA',
#  'L1NC34.SA',
#  'L1IN34.SA',
#  'L1YV34.SA',
#  'L1KQ34.SA',
#  'L1YG34.SA',
#  'L1OE34.SA',
#  'LOWC34.SA',
#  'L1UL34.SA',
#  'L1MN34.SA',
#  'L1YB34.SA',
#  'M1TB34.SA',
#  'MACY34.SA',
#  'M1RO34.SA',
#  'M1PC34.SA',
#  'MKLC34.SA',
#  'M1KT34.SA',
#  'M1TT34.SA',
#  'M1MC34.SA',
#  'M1LM34.SA',
#  'M1AS34.SA',
#  'M1TC34.SA',
#  'M1XI34.SA',
#  'M1KC34.SA',
#  'MCDC34.SA',
#  'M1CK34.SA',
#  'MDTC34.SA',
#  'M1LC34.SA',
#  'MELI34.SA',
#  'MRCK34.SA',
#  'M1TD34.SA',
#  'M1GM34.SA',
#  'M1CH34.SA',
#  'MUTC34.SA',
#  'MSFT34.SA',
#  'M1AA34.SA',
#  'M1UF34.SA',
#  'M1BT34.SA',
#  'M1RN34.SA',
#  'M1HK34.SA',
#  'M1CB34.SA',
#  'MDLZ34.SA',
#  'M1DB34.SA',
#  'M1NS34.SA',
#  'MCOR34.SA',
#  'MOSC34.SA',
#  'M1SI34.SA',
#  'M1SC34.SA',
#  'N1DA34.SA',
#  'N1GG34.SA',
#  'N1OV34.SA',
#  'N1WG34.SA',
#  'N1TA34.SA',
#  'NETE34.SA',
#  'NFLX34.SA',
#  'N1BI34.SA',
#  'E1DU34.SA',
#  'N1WL34.SA',
#  'N1EM34.SA',
#  'N1WS34.SA',
#  'N1WS35.SA',
#  'NEXT34.SA',
#  'N1IC34.SA',
#  'N1LS34.SA',
#  'N1IS34.SA',
#  'NOKI34.SA',
#  'NMRH34.SA',
#  'J1WN34.SA',
#  'N1SC34.SA',
#  'N1TR34.SA',
#  'NOCG34.SA',
#  'N1CL34.SA',
#  'N1VS34.SA',
#  'N1VO34.SA',
#  'N1RG34.SA',
#  'NUBR33.SA',
#  'N1UE34.SA',
#  'NVDC34.SA',
#  'N1VR34.SA',
#  'N1XP34.SA',
#  'OXYP34.SA',
#  'O1KT34.SA',
#  'O1DF34.SA',
#  'O1MC34.SA',
#  'O1KE34.SA',
#  'ORLY34.SA',
#  'I1XC34.SA',
#  'O1TI34.SA',
#  'P1AC34.SA',
#  'P1KG34.SA',
#  'PAGS34.SA',
#  'P2LT34.SA',
#  'P1HC34.SA',
#  'P1AY34.SA',
#  'P1YC34.SA',
#  'PYPL34.SA',
#  'P1NR34.SA',
#  'P1BC34.SA',
#  'P1KI34.SA',
#  'P1RG34.SA',
#  'PTCH34.SA',
#  'P2IN34.SA',
#  'PFIZ34.SA',
#  'PGCO34.SA',
#  'PHMO34.SA',
#  'P1SX34.SA',
#  'P1DD34.SA',
#  'P1NW34.SA',
#  'P1IO34.SA',
#  'P2LN34.SA',
#  'PNCS34.SA',
#  'P1KX34.SA',
#  'P1PG34.SA',
#  'P1PL34.SA',
#  'P1FG34.SA',
#  'P2CO34.SA',
#  'P1LD34.SA',
#  'P1DT34.SA',
#  'P1UK34.SA',
#  'T1LK34.SA',
#  'P1EG34.SA',
#  'P1SA34.SA',
#  'P1HM34.SA',
#  'P1VH34.SA',
#  'Q1RV34.SA',
#  'QCOM34.SA',
#  'Q1UA34.SA',
#  'Q1UE34.SA',
#  'R1LC34.SA',
#  'R1JF34.SA',
#  'RDSA34.SA',
#  'R1IN34.SA',
#  'R1EG34.SA',
#  'R2DF34.SA',
#  'REGN34.SA',
#  'R1FC34.SA',
#  'R1EL34.SA',
#  'R1SG34.SA',
#  'R1MD34.SA',
#  'RIOT34.SA',
#  'R2HH34.SA',
#  'R1HI34.SA',
#  'R2BL34.SA',
#  'R1OK34.SA',
#  'R1KU34.SA',
#  'R1OL34.SA',
#  'R1OP34.SA',
#  'ROST34.SA',
#  'R1CL34.SA',
#  'RDSA35.SA',
#  'R1YA34.SA',
#  'SPGI34.SA',
#  'SSFO34.SA',
#  'BCSA34.SA',
#  'SAPP34.SA',
#  'S1RP34.SA',
#  'S1BA34.SA',
#  'SCHW34.SA',
#  'S1TX34.SA',
#  'S1EA34.SA',
#  'S1GE34.SA',
#  'S1RE34.SA',
#  'N1OW34.SA',
#  'S1BS34.SA',
#  'SBNY34.SA',
#  'SIMN34.SA',
#  'SRXM34.SA',
#  'S1KM34.SA',
#  'S1SL34.SA',
#  'S1LG34.SA',
#  'S1NN34.SA',
#  'S1NA34.SA',
#  'S2QS34.SA',
#  'SNEC34.SA',
#  'S1OU34.SA',
#  'S1PL34.SA',
#  'S1PO34.SA',
#  'S1SN34.SA',
#  'S1WK34.SA',
#  'S1TT34.SA',
#  'S1TE34.SA',
#  'SLBC34.SA',
#  'STMN34.SA',
#  'S2TO34.SA',
#  'S1YK34.SA',
#  'S1MF34.SA',
#  'S1IV34.SA',
#  'S1YM34.SA',
#  'S1YF34.SA',
#  'S1NP34.SA',
#  'S1YY34.SA',
#  'T1RO34.SA',
#  'TSMC34.SA',
#  'TAKP34.SA',
#  'T1TW34.SA',
#  'T1AL34.SA',
#  'TPRY34.SA',
#  'T1EL34.SA',
#  'T1EC34.SA',
#  'T1FX34.SA',
#  'TLNC34.SA',
#  'T2PX34.SA',
#  'T1SS34.SA',
#  'TXSA34.SA',
#  'TSLA34.SA',
#  'T1EV34.SA',
#  'T1XT34.SA',
#  'S1JM34.SA',
#  'P1GR34.SA',
#  'S1HW34.SA',
#  'T1SO34.SA',
#  'TMOS34.SA',
#  'TJXC34.SA',
#  'T1MU34.SA',
#  'TMCO34.SA',
#  'T1SC34.SA',
#  'T1DG34.SA',
#  'RIGG34.SA',
#  'TRVC34.SA',
#  'T1RI34.SA',
#  'T1WL34.SA',
#  'TWTR34.SA',
#  'TSNF34.SA',
#  'U1BE34.SA',
#  'UBSG34.SA',
#  'U1DR34.SA',
#  'P2AT34.SA',
#  'U1LT34.SA',
#  'U1AI34.SA',
#  'ULEV34.SA',
#  'U1NL34.SA',
#  'UPAC34.SA',
#  'U1AL34.SA',
#  'U1RI34.SA',
#  'UNHH34.SA',
#  'U1HS34.SA',
#  'U1NM34.SA',
#  'UPSS34.SA',
#  'U2PW34.SA',
#  'USSX34.SA',
#  'VLOE34.SA',
#  'VLYB34.SA',
#  'V1AR34.SA',
#  'V2EE34.SA',
#  'V1TA34.SA',
#  'VRSN34.SA',
#  'V1RS34.SA',
#  'VERZ34.SA',
#  'VRTX34.SA',
#  'VFCO34.SA',
#  'V2ME34.SA',
#  'V1IP34.SA',
#  'V1OD34.SA',
#  'V1NO34.SA',
#  'V1MC34.SA',
#  'W1AB34.SA',
#  'WALM34.SA',
#  'WGBA34.SA',
#  'W1MG34.SA',
#  'W1MC34.SA',
#  'WATC34.SA',
#  'W1SO34.SA',
#  'W2YF34.SA',
#  'W1EC34.SA',
#  'W1BO34.SA',
#  'WFCO34.SA',
#  'W1EL34.SA',
#  'W2ST34.SA',
#  'WABC34.SA',
#  'W1DC34.SA',
#  'WUNI34.SA',
#  'W1BK34.SA',
#  'W1RK34.SA',
#  'W1YC34.SA',
#  'W1HR34.SA',
#  'W1MB34.SA',
#  'W1LT34.SA',
#  'W1IX34.SA',
#  'W1DA34.SA',
#  'W1PP34.SA',
#  'W1RB34.SA',
#  'G1WW34.SA',
#  'W1YN34.SA',
#  'X1EL34.SA',
#  'X1LN34.SA',
#  'X1YL34.SA',
#  'YUMR34.SA',
#  'Z1BR34.SA',
#  'Z2EN34.SA',
#  'Z2LL34.SA',
#  'Z1BH34.SA',
#  'Z1IO34.SA',
#  'Z1TS34.SA',
#  'Z1OM34.SA',
#  'Z1TO34.SA',
#  'ACNB34.SA',
#  'AIGB34.SA',
#  'AXPB34.SA',
#  'ATTB34.SA',
#  'BERK34.SA',
#  'BONY34.SA',
#  'BOEI34.SA',
#  'BMYB34.SA',
#  'DUKB34.SA',
#  'DDNB34.SA',
#  'FDXB34.SA',
#  'FMXB34.SA',
#  'GDBR34.SA',
#  'HONB34.SA',
#  'HPQB34.SA',
#  'IBMB34.SA',
#  'JNJB34.SA',
#  'KMBB34.SA',
#  'KHCB34.SA',
#  'LMTB34.SA',
#  'METB34.SA',
#  'MSBR34.SA',
#  'PEPB34.SA',
#  'SBUB34.SA',
#  'TGTB34.SA',
#  'TEXA34.SA',
#  'VISA34.SA',
#  'DISB34.SA',
#  'XRXB34.SA',
#  'AMZO34.SA',
#  'CATP34.SA',
#  'CHVX34.SA',
#  'COCA34.SA',
#  'COLG34.SA',
#  'MSCD34.SA',
#  'NIKE34.SA',
#  'ORCL34.SA',
#  'RYTT34.SA',
#  'SLBG34.SA',
#  'TIFF34.SA',
#  'USBC34.SA',
#  'XPBR31.SA']

# %%
import yfinance as yf

# %%
bdf_fechamentos = yf.download(bdr_sa, start = '2024-01-01')['Close']
bdf_fechamentos
# Out:
# [*********************100%%**********************]  708 of 708 completed
# ERROR:yfinance:
# 65 Failed downloads:
# ERROR:yfinance:['A1BM34.SA', 'S2TO34.SA', 'H1ZN34.SA', 'INGG3.SA', 'X1LN34.SA', 'A1LX34.SA', 'F1RI34.SA', 'C1HI34.SA', 'S1GE34.SA', 'E1XC34MONDE.SA', 'D1RE34.SA', 'LBRN34.SA', 'A1MX34.SA', 'A1UA34.SA', 'A1MB34.SA', 'N1LS34.SA', 'L1BT35.SA', 'A1BB34.SA', 'FLTC34.SA', 'K1CS34.SA', 'E1NI34.SA', 'C1HL34.SA', 'RDSA34.SA', 'C1SU34.SA', 'SLBC34.SA', 'CAJI34.SA', 'C1ER34.SA', 'C1OU34.SA', 'FBOK34.SA', 'A1NT34.SA', 'ATVI34.SA', 'V1AR34.SA', 'C1XO34.SA', 'M1XI34.SA', 'U1NL34.SA', 'DCVY35.SA', 'A2MC34.SA', 'P1KI34.SA', 'ISBC34.SA', 'W1BK34.SA', 'E1FX34.SA', 'SBNY34.SA', 'LSXM35.SA', 'NUBR33.SA', 'P1BC34.SA', 'A2VL34.SA', 'TIFF34.SA', 'Z2EN34.SA', 'C1TX34.SA', 'LSXM34.SA', 'L1IN34.SA', 'D1IS34.SA', 'L1BT34.SA', 'RDSA35.SA', 'I1NF34.SA', 'B1BL34.SA', 'CRHP34.SA', 'F1RC34.SA', 'PTCH34.SA', 'W1RK34.SA', 'BHPG34.SA', 'TWTR34.SA', 'C1EO34.SA', 'L1FC34.SA']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ERROR:yfinance:['E2PD34.SA']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2024-01-01 -> 2024-05-14)')
# Ticker      A1AP34.SA  A1BB34.SA  A1BM34.SA  A1CR34.SA  A1DI34.SA   A1DM34.SA  \
# Date
# 2024-01-02  19.290001        NaN        NaN  47.200001      486.0  359.000000
# 2024-01-03  18.780001        NaN        NaN  47.650002      466.5  363.600006
# 2024-01-04  18.540001        NaN        NaN  47.070000      466.5  354.000000
# 2024-01-05  18.820000        NaN        NaN  47.450001      466.5  345.000000
# 2024-01-08  18.820000        NaN        NaN  47.560001      466.5  345.000000
# ...               ...        ...        ...        ...        ...         ...
# 2024-05-08  23.600000        NaN        NaN  50.049999      489.0  314.029999
# 2024-05-09  24.290001        NaN        NaN  52.389999      489.0  319.040009
# 2024-05-10  24.049999        NaN        NaN  53.500000      489.0  323.799988
# 2024-05-13  24.320000        NaN        NaN  53.500000      489.0  323.839996
# 2024-05-14  24.120001        NaN        NaN  53.099998        NaN  315.700012
#
# Ticker       A1EE34.SA  A1EG34.SA   A1EN34.SA   A1EP34.SA  ...  XRXB34.SA  \
# Date                                                       ...
# 2024-01-02  174.960007  28.030001  252.750000  194.800003  ...  90.629997
# 2024-01-03  174.960007  27.719999  252.750000  194.800003  ...  77.849998
# 2024-01-04  174.960007  27.930000  252.750000  194.800003  ...  80.320000
# 2024-01-05  174.960007  27.930000  252.750000  194.800003  ...  80.320000
# 2024-01-08  174.960007  27.930000  252.750000  194.800003  ...  81.000000
# ...                ...        ...         ...         ...  ...        ...
# 2024-05-08  187.720001  32.849998  253.889999  230.550003  ...  67.830002
# 2024-05-09  187.720001  33.509998  253.889999  230.550003  ...  67.830002
# 2024-05-10  187.720001  34.200001  253.889999  230.550003  ...  67.830002
# 2024-05-13  187.720001  34.200001  253.889999  230.550003  ...  67.830002
# 2024-05-14         NaN  34.160000         NaN         NaN  ...        NaN
#
# Ticker       YUMR34.SA   Z1BH34.SA  Z1BR34.SA   Z1IO34.SA  Z1OM34.SA  \
# Date
# 2024-01-02  315.329987  172.199997  43.000000  167.500000      13.47
# 2024-01-03  315.329987  172.199997  43.000000  167.500000      13.21
# 2024-01-04  315.329987  172.199997  41.270000  167.500000      13.18
# 2024-01-05  312.959991  172.199997  41.270000  167.500000      13.01
# 2024-01-08  314.649994  148.889999  41.270000  167.500000      13.53
# ...                ...         ...        ...         ...        ...
# 2024-05-08  364.679993  158.250000  52.400002  213.149994      12.46
# 2024-05-09  364.679993  158.250000  52.400002  213.149994      12.63
# 2024-05-10  364.679993  158.250000  52.400002  227.240005      12.70
# 2024-05-13  364.679993  158.250000  52.400002  227.240005      12.99
# 2024-05-14         NaN         NaN        NaN         NaN      12.98
#
# Ticker      Z1TO34.SA  Z1TS34.SA  Z2EN34.SA  Z2LL34.SA
# Date
# 2024-01-02  25.420000  60.540001        NaN  23.420000
# 2024-01-03  25.420000  59.599998        NaN  23.420000
# 2024-01-04  25.420000  59.349998        NaN  22.299999
# 2024-01-05  25.420000  59.520000        NaN  22.299999
# 2024-01-08  25.420000  59.520000        NaN  22.299999
# ...               ...        ...        ...        ...
# 2024-05-08  26.190001  52.189999        NaN  18.650000
# 2024-05-09  26.190001  53.900002        NaN  18.650000
# 2024-05-10  26.190001  54.400002        NaN  18.650000
# 2024-05-13  26.190001  54.400002        NaN  18.650000
# 2024-05-14        NaN  54.099998        NaN        NaN
#
# [92 rows x 708 columns]
